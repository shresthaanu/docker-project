# %%
import numpy as np
from sklearn.model_selection import train_test_split
import pandas as pd
from sklearn import preprocessing
from sklearn.model_selection import KFold, StratifiedKFold

# %% [markdown]
# # read data

# %%
df=pd.read_csv("data/iris1.csv")
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# # analyse which k fold works better using distribution of data

# %%
d=df.values
X=d[:,0:4]
y=d[:,4]

print("Using K-fold cross validation")
kf = KFold(n_splits=5)
for train_index, test_index in kf.split(X):
    X_train=X[train_index]
    y_train=y[train_index]
    X_test=X[test_index]
    y_test=y[test_index]
    
    
    import matplotlib.mlab as mlab
    import matplotlib.pyplot as plt
    num_bins=7
    n, bins, patches = plt.hist(y_train, num_bins, facecolor='blue', alpha=0.5)
    plt.show()

print("Using Stratified K-fold cross validation")
kf = StratifiedKFold(n_splits=5)
for train_index, test_index in kf.split(X,y):
    X_train=X[train_index]
    y_train=y[train_index]
    X_test=X[test_index]
    y_test=y[test_index]
    
    import matplotlib.mlab as mlab
    import matplotlib.pyplot as plt
    num_bins=7
    n, bins, patches = plt.hist(y_train, num_bins, facecolor='red', alpha=0.5)
    plt.show()
# Out:
# Using K-fold cross validation
# Using Stratified K-fold cross validation

# %% [markdown]
# From the graph we can see that Stratified K-fold cross validation makes the target label equally distributed in all the train sets and in the test sets than K-fold cross validation. Thus, we can use strafied cross validation.
